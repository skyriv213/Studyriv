# %% [markdown]
# <a href="https://colab.research.google.com/github/skyriv213/Studyriv/blob/main/machineLearning/BasicColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![스크린샷 2025-04-03 오후 10.13.52.png](data:image/png;base64,...)
